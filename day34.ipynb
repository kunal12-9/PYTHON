# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ktail\\Downloads\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df2 = pd.read_csv("C:\\Users\\ktail\\Downloads\\tips.csv")
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df3 = pd.read_csv("C:\\Users\\ktail\\Downloads\\covid_toy.csv")
df3
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df3.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df3.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df4 = pd.read_csv("C:\\Users\\ktail\\Downloads\\placement.csv")
df4
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df4.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df4.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df4.describe() #staticaly view of data
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df4.info() #data type information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df4 = df4.iloc[:4 ,:3] ### [row range , coulam range]
top_left_corner_df4
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df4.loc[1:3 ,["cgpa" , "placed"]] #### loc[row_range, coulum_names]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p = df4.dtypes ### it returns true if there any missing dat in dat frame otherwise retruns false.
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df4.empty ### it returns true if there anty missing data in dataframe otherwise return false.
b
# Out:
# False

# %%
df4.isnull().sum() ### for check missing values.
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df4.dropna ### for remove missing row
# Out:
# <bound method DataFrame.dropna of     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]>

# %%
df5 = pd.read_csv("C:\\Users\\ktail\\Downloads\\flipkart.csv")
df5
# Out:
#                                           CGtC98 href  \
# 0   https://www.flipkart.com/samsung-galaxy-s24-5g...
# 1   https://www.flipkart.com/samsung-galaxy-s24-5g...
# 2   https://www.flipkart.com/samsung-galaxy-s24-fe...
# 3   https://www.flipkart.com/realme-14-pro-5g-sued...
# 4   https://www.flipkart.com/samsung-galaxy-s24-5g...
# 5   https://www.flipkart.com/samsung-galaxy-s24-5g...
# 6   https://www.flipkart.com/realme-gt-6-razor-gre...
# 7   https://www.flipkart.com/realme-gt-6-fluid-sil...
# 8   https://www.flipkart.com/samsung-galaxy-a36-5g...
# 9   https://www.flipkart.com/vivo-v50-5g-rose-red-...
# 10  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 11  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 12  https://www.flipkart.com/realme-14-pro-5g-sued...
# 13  https://www.flipkart.com/samsung-galaxy-s24-fe...
# 14  https://www.flipkart.com/vivo-t3-ultra-frost-g...
# 15  https://www.flipkart.com/realme-14-pro-5g-bika...
# ...

# %%
df5.head()
# Out:
#                                          CGtC98 href  \
# 0  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 1  https://www.flipkart.com/samsung-galaxy-s24-5g...
# 2  https://www.flipkart.com/samsung-galaxy-s24-fe...
# 3  https://www.flipkart.com/realme-14-pro-5g-sued...
# 4  https://www.flipkart.com/samsung-galaxy-s24-5g...
#
#                                           DByuf4 src          uu79Xy  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 1  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 2  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 3  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 4  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
#
#                                          KzDlHZ  XQDdHH  \
# 0   SAMSUNG Galaxy S24 5G (Marble Gray, 128 GB)     4.5
# 1    SAMSUNG Galaxy S24 5G (Onyx Black, 256 GB)     4.5
# ...

# %%
df5.tail()
# Out:
#                                           CGtC98 href  \
# 21  https://www.flipkart.com/oneplus-13r-5g-nebula...
# 22  https://www.flipkart.com/oneplus-13r-5g-astral...
# 23  https://www.flipkart.com/vivo-v50-5g-starry-ni...
# 24                                                NaN
# 25                                                NaN
#
#                                            DByuf4 src          uu79Xy  \
# 21  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 22  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 23  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 24                                                NaN             NaN
# 25                                                NaN             NaN
#
#                                    KzDlHZ  XQDdHH  \
# 21   OnePlus 13R 5G (Nebula Noir, 512 GB)     4.5
# 22  OnePlus 13R 5G (Astral Trail, 512 GB)     4.5
# 23     vivo V50 5G (Starry Night, 256 GB)     4.5
# ...
