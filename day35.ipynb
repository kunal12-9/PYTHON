# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ktail\\Downloads\\placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head() ### top 5
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail() ### bottom 5
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4 ,:3] ### iloc[row range , coulam range] ---> its not include last indexing value
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[1:3 ,["cgpa" , "placed"]] #### loc[row_range, coulum_names]
# Out:
#    cgpa  placed
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1

# %%
p=df.dtypes #data type information
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty 
b
# Out:
# False

# %%
df.isnull().sum() ###for check missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df = df.dropna() ## for remove missing row

# %%
i = df.ndim   ### number of axes (its 2)
i
# Out:
# 2

# %%
t = df.shape # shape = n(rows), n(coulams)
t
# Out:
# (100, 3)

# %%
d = df.size ### row count * coulam count = total
d
# Out:
# 300

# %%
a = df.values # get numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = "resume_score")
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df.sort

# %%
# x =  = df.astype(int) # type conversation
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
#t = df.add(4)
#t
df['cgpa'] = df['cgpa'].add(4)
df
# df['resume_score']=df['resume_score'].add(5)
# df['placed']=df['placed'].add(6)
# df['cgpa']
# df['resume_score']
# df['placed']
# Out:
#     cgpa  resume_score  placed
# 0     24          6.52       1
# 1     22          5.17       0
# 2     24          8.86       1
# 3     22          7.27       1
# 4     23          7.30       1
# ..   ...           ...     ...
# 95    22          6.38       0
# 96    24          7.76       1
# 97    22          7.78       0
# 98    24          5.63       1
# 99    22          6.61       0
#
# [100 rows x 3 columns]

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            21.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q = df.min()
q
# Out:
# cgpa            17.00
# resume_score     4.95
# placed           0.00
# dtype: float64

# %%
#x=1,2,3,4,5
#mean =1+2+3+4+5/5 =15/5 =3

#x =1,2,3,4,5,100
#means= = 115/6 =19.3

# %%
r = df['cgpa'].mean()
r
# Out:
# np.float64(18.47)

# %%
s = df['cgpa'].median()
s
# Out:
# np.float64(18.0)

# %%
df.mean()
# Out:
# cgpa            18.4700
# resume_score     6.9305
# placed           0.5000
# dtype: float64

# %%
g = df.filter(items = ['cgpa','placed'])
g
df[['cgpa','placed']] ##second option of filtring
# Out:
#     cgpa  placed
# 0     20       1
# 1     18       0
# 2     20       1
# 3     18       1
# 4     19       1
# ..   ...     ...
# 95    18       0
# 96    20       1
# 97    18       0
# 98    20       1
# 99    18       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items = [5,6] , axis =0)  ### axis =0 means row wise opration
s
# Out:
#    cgpa  resume_score  placed
# 5    24          6.19       1
# 6    21          7.09       0

# %%
s = df.to_dict()
s
# Out:
# {'cgpa': {0: 24,
#   1: 22,
#   2: 24,
#   3: 22,
#   4: 23,
#   5: 24,
#   6: 21,
#   7: 22,
#   8: 22,
#   9: 23,
#   10: 22,
#   11: 21,
#   12: 22,
#   13: 24,
#   14: 23,
#   15: 24,
#   16: 24,
#   17: 23,
#   18: 21,
#   19: 22,
#   20: 21,
#   21: 22,
#   22: 22,
#   23: 22,
#   24: 24,
#   25: 23,
#   26: 22,
#   27: 21,
#   28: 23,
#   29: 22,
#   30: 23,
#   31: 21,
#   32: 21,
#   33: 24,
#   34: 24,
#   35: 24,
#   36: 24,
#   37: 25,
#   38: 22,
#   39: 23,
#   40: 24,
#   41: 24,
#   42: 22,
#   43: 24,
#   44: 21,
#   45: 24,
#   46: 21,
#   47: 23,
#   48: 21,
#   49: 21,
#   50: 24,
#   51: 22,
#   52: 21,
#   53: 22,
#   54: 21,
#   55: 22,
#   56: 22,
#   57: 22,
#   58: 22,
#   59: 21,
#   60: 21,
#   61: 22,
#   62: 21,
#   63: 24,
#   64: 23,
#   65: 22,
#   66: 24,
#   67: 22,
#   68: 22,
#   69: 24,
#   70: 23,
#   71: 23,
#   72: 23,
#   73: 21,
#   74: 21,
#   75: 22,
#   76: 25,
#   77: 21,
#   78: 21,
#   79: 21,
#   80: 23,
#   81: 22,
#   82: 23,
# ...

# %%
q = df.to_string()
q
# Out:
# '    cgpa  resume_score  placed\n0     24          6.52       1\n1     22          5.17       0\n2     24          8.86       1\n3     22          7.27       1\n4     23          7.30       1\n5     24          6.19       1\n6     21          7.09       0\n7     22          6.29       0\n8     22          6.71       0\n9     23          7.12       1\n10    22          6.35       0\n11    21          6.54       0\n12    22          7.01       0\n13    24          5.09       1\n14    23          6.25       1\n15    24          5.93       1\n16    24          7.64       1\n17    23          8.71       1\n18    21          5.88       0\n19    22          8.11       1\n20    21          8.06       0\n21    22          7.64       0\n22    22          5.77       0\n23    22          7.13       0\n24    24          6.18       1\n25    23          5.68       1\n26    22          6.47       0\n27    21          6.15       0\n28    23          7.67       1\n29    22          7.30       0\n30   
# ...

# %%
e = df.to_csv("path_location")

# %%
idx = df.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label =  df.columns[0] # first coulam lebal
label
# Out:
# 'cgpa'

# %%
p = df.columns.tolist() # list of coulm lables
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = df.columns.values #array of coulam lables
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns= {'cgpa':'updated_cgpa',
                        'resume_score':'semester_marks'}) #how to rename a coulam
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             24            6.52       1
# 1             22            5.17       0
# 2             24            8.86       1
# 3             22            7.27       1
# 4             23            7.30       1
# ..           ...             ...     ...
# 95            22            6.38       0
# 96            24            7.76       1
# 97            22            7.78       0
# 98            24            5.63       1
# 99            22            6.61       0
#
# [100 rows x 3 columns]

# %%
#case sensitive
#if mistakely word mismatched new coulam crated
df['Cgpan'] = df['cgpa'].astype(int)

# %%
a = df.drop(columns = ['cgpa' , 'placed'])
a

# %%
df['new']= df['cgpa'].where(df['cgpa']>6,other=0)

# %%
df.sample(8)
# Out:
#     cgpa  resume_score  placed  Cgpan  new
# 76    25          5.50       1     25   25
# 55    22          6.87       1     22   22
# 70    23          7.41       1     23   23
# 21    22          7.64       0     22   22
# 82    23          6.06       1     23   23
# 2     24          8.86       1     24   24
# 17    23          8.71       1     23   23
# 92    21          6.18       0     21   21

# %%
# make notes df merging , contenacting

# %%
data1= {
    "name": ["Sally" , "Mary" , "John"],
    "age": [50,40,30]
}
data2 =  {
    "name": ["Sally" , "peter" , "Micky"],
    "age": [77,42,22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

newdf = df1.merge(df2, how = 'right')

# %%
newdf
# Out:
#     name  age
# 0  Sally   77
# 1  peter   42
# 2  Micky   22

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech','B.A','Bcom','B.hons']}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd

# %%
df2
# Out:
#      Name  Age    Address Qualification
# 0    Abhi   17     Nagpur         Btech
# 1  Ayushi   14     Kanpur           B.A
# 2  Dhiraj   12  Allahabad        M.tech
# 3  Hitesh   52    Kannuaj           Mba

# %%
new_dt = pd.concat([df1,df2])
#new_d

# %%
df = pd.merge(df1,df2, on = 'Address', how = 'inner')
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14             B.A
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12          M.tech
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52             Mba
