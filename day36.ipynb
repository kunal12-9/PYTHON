# %%
# EDA ==> Exploratory Data analysis

# %% [markdown]
# # parts of EDA

# %%
# 1. Univariate analysis ==> analysis on a single independent coulam
# 2. Bivariate analysis ==> analysis on two coulam
# 3. Multivariate analysis ==> analysis on more than 2 coulms

# %%
#data types
#1. numerical data ==> continous dfata ===> age(year, month, days) , height , weight etc.
#2 categorical Data ==> descrete  0dtaa ==> total number of employes , martial status, student result

# %%
import numpy as np
import pandas as pd

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\ktail\\Downloads\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # 1. Univariate Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# if we want to see actual values then we use value_count()

df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
# if we wnat to find out percentage  then use pie chart
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# if we have numericsl data then we use Histogram
# beacause if finds the distribution

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
#3 box plot
# for find our outliers

#1. lower fence
#2. 25% data
#3 IQR (Inter quartile Range) (75% - 25%)
#4 75% data
#5 upper fence

# %%
# x =1,2,3,4,5
# means = (1,2,3,4,5)/5 = 15/5 =3 ### here 100 Is Outlier
# x = 1,2,3,4,5
# means = 15+100/6 =115/6 =19.3

# %%
sns.boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips = pd.read_csv("C:\\Users\\ktail\\Downloads\\tips.csv")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # bivariate analysis

# %%
#. scatterplot(Numerical coulum - numerical coulum)

# %%
sns.scatterplot(x= tips['total_bill']  , #df['total_bill']
                y = tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Multivariate analysis

# %%
sns.scatterplot(x="total_bill" , y = "tip" , data = tips , hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill" ,
                y = "tip" , data = tips ,
                hue = tips['sex'] , style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
